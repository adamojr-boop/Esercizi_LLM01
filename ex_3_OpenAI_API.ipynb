# %% [markdown]
# # Esercizio 3
#
# **Traccia:** Crea un prompt che riassuma un articolo di notizie in un singolo paragrafo di al massimo 255 caratteri.
#
# **Obiettivo:** Prendere un testo lungo e condensarlo nei punti essenziali.

# %%
# %pip install python-dotenv openai

# %%
# TODO Inizializza il client di Open AI

import os, openai
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv('.env') # Read the .env file

# Configure OpenAI client
openai.api_key = os.environ['OPENAI_API_KEY']

client = OpenAI()

# %%
input_text = input("Enter text: ")

complention = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
         {"role": "system", "content": "sei un assistente in grado di analizzare testi e fornire sintesi chiare e concise da un articolo di notizie in un singolo paragrafo di al massimo 255 caratteri. Devi prendere un testo lungo e condensarlo nei punti essenziali."},
        {"role": "user", "content": input_text}
    ],
)

print(complention.choices[0].message.content)
# Out:
# Sembra che tu non abbia fornito alcun testo da riassumere. Per favore, inserisci l'articolo o il contenuto che desideri analizzare, e sarò felice di aiutarti a fare una sintesi!
